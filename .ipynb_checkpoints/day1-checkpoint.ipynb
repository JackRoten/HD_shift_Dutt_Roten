# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('hgtest1.csv')

# %%
df.columns = ['ds', 'nA']

# %%
df.max()
# Out:
# ds    313.684612
# nA      1.000000
# dtype: float64

# %%
plt.figure(figsize=(31,15),  facecolor = 'w')
plt.plot(df.ds, df.nA)

# %%
firstpeak = df2[df2.ds <30 ].max()
secondpeak = df2[(df2.ds> 30) & (df2.ds <40)].max()

# %%
df2 =  pd.read_csv('hgdoubletmeasurement.csv')
df2.columns = ['ds', 'nA']
plt.figure(figsize=(31,15),  facecolor = 'w')
plt.plot(df2.ds, df2.nA)

# %%
firstpeak = df2[df2.ds <30 ].max()
secondpeak = df2[(df2.ds> 30) & (df2.ds <40)].max()

# %%
firstpeak
# Out:
# ds    29.999912
# nA     1.000000
# dtype: float64

# %%
secondpeak
# Out:
# ds    39.999864
# nA     1.330561
# dtype: float64

# %%
deltax = (secondpeak[0] - firstpeak[0])/12
print(str(deltax) + " Angstroms")
# Out:
# 0.8333293333333337 Angstroms

# %% [markdown]
# Abo

# %% [markdown]
# # thrid trial hg
# Entry slit to 10 micrometers and output slit to 20 micrometers

# %%
df3 =  pd.read_csv('hgdoubletmeasurement2.csv')
df3.columns = ['ds', 'nA']
plt.figure(figsize=(31,15),  facecolor = 'w')
plt.plot(df3.ds, df3.nA)
firstpeak3 = df3[df3.ds <30 ].max()
secondpeak3 = df3[(df3.ds> 30) & (df3.ds <40)].max()
plt.axvline(x=firstpeak3[0])
plt.axvline(x=secondpeak3[0])
plt.show()

# %%
deltax3 = (secondpeak3[0] - firstpeak3[0])/12
print(str(deltax3) + " Angstroms")
# Out:
# 0.8021413333333335 Angstroms

# %% [markdown]
# # Trial 5

# %%
df4 = pd.read_csv('hgmeasurement3.csv')
df4.columns = ['ds', 'nA']
firstpeak4 = df4[(df4.ds< 100) & (df4.ds >  10) ]
firstpeak4[firstpeak4['nA'] == 0.000302]
# Out:
#                ds        nA
# 53368   10.741848  0.000302
# 215961  43.472336  0.000302
# 228571  46.011464  0.000302
# 263251  52.991104  0.000302
# 273298  55.014272  0.000302
# 295946  59.574112  0.000302
# 367182  73.913304  0.000302

# %%
firstpeak4 = firstpeak4[firstpeak4.nA == firstpeak4.nA.max()]

# %%
f = df4
f = f[f.ds > 100]
f = f.reset_index(drop = True)
f.iloc[-1]
# Out:
# ds    190.384936
# nA      0.000503
# Name: 449008, dtype: float64

# %%
# Out:
# index    496774.000000
# ds          100.000280
# nA            0.000305
# Name: 1, dtype: float64

# %%
df4 = pd.read_csv('hgmeasurement3.csv')
df4.columns = ['ds', 'nA']
firstpeak4 = df4[(df4.ds< 100) & (df4.ds >  10) ]
firstpeak4 = firstpeak4[firstpeak4.nA == firstpeak4.nA.max()]
firstpeak4 = firstpeak4.reset_index(drop = True)

secondpeak4 = df4[(df4.ds< 170) & (df4.ds > 160)]
secondpeak4 = secondpeak4[secondpeak4.nA == secondpeak4.nA.max()]
secondpeak4 = secondpeak4.reset_index(drop = True)
secondpeak4.ds[0]

thirdpeak4 = df4[(df4.ds< 175) & (df4.ds > 150)]
thirdpeak4 = thirdpeak4[thirdpeak4.nA == thirdpeak4.nA.max()]
thirdpeak4 = thirdpeak4.reset_index(drop = True)
thirdpeak4.ds[0]
plt.figure(figsize=(31,15),  facecolor = 'w')
plt.plot(df4.ds, df4.nA)

plt.axvline(x=firstpeak4.ds[0])
plt.axvline(x=secondpeak4.ds[0])
plt.axvline(x=thirdpeak4.ds[0])

plt.show()

# %%
print((firstpeak4.ds[0] - secondpeak4.ds[0])/12)

print((secondpeak4.ds[0] - thirdpeak4.ds[0])/12)
# Out:
# -11.439156666666667
# -0.5626279999999989

# %% [markdown]
# ## SCALING a = 1.0055 b = 0.1375\
# True = a*measure + b

# %%
df5 = pd.read_csv('hgmeasurement4.csv')
df5.columns = ['ds', 'nA']
plt.figure(figsize=(31,15),  facecolor = 'w')
plt.plot(df5.ds, df5.nA)
plt.show()

# %%
df656 = pd.read_csv('HD_5Angstroms_656nm.csv')
df656 = df656.reset_index(drop = True)
df656.columns = ['ds', 'nA']

# %% [markdown]
# # Trying to denoise signal with different filters
# We will try 3 different filters:
# 1. savitzky_golay
# 2. medfilt
# 3. lfilter
#
# The lfilter showed to be the most effective and efficient algorithm in terms of performance and time taken.

# %%
plt.figure(figsize=(31,15),  facecolor = 'w')
plt.plot(df656.ds, df656.nA)
plt.show()

# %%
df656a = df656[(df656.ds < 750) & (df656.ds > 600)].reset_index(drop = True)

# %%
plt.figure(figsize=(31,15),  facecolor = 'w')
plt.plot(df656a.ds, df656a.nA)
plt.show()

# %%
df656a.nA.max()
# Out:
# 0.93110954

# %%
h656a = df656a[df656a.nA == df656a.nA.max()].reset_index(drop = True)
d656a = df656[(df656.ds < 750) & (df656.ds > 680)]
d656a = d656a[d656a.nA == d656a.nA.max()].reset_index(drop = True)
#print(h656a.ds[0])
print(d656a)
print(h656a)
# Out:
#            ds        nA
# 0  689.756672  0.333747
#            ds       nA
# 0  669.387384  0.93111

# %%
shift656a = h656a - d656a
shift656a.ds[0]
# Out:
# -20.369287999999983

# %%
shift656a.ds[0]/12
# Out:
# -1.6974406666666653

# %%
def savitzky_golay(y, window_size, order, deriv=0, rate=1):

    import numpy as np
    from math import factorial

    try:
        window_size = np.abs(np.int(window_size))
        order = np.abs(np.int(order))
    except ValueError, msg:
        raise ValueError("window_size and order have to be of type int")
    if window_size % 2 != 1 or window_size < 1:
        raise TypeError("window_size size must be a positive odd number")
    if window_size < order + 2:
        raise TypeError("window_size is too small for the polynomials order")
    order_range = range(order+1)
    half_window = (window_size -1) // 2
    # precompute coefficients
    b = np.mat([[k**i for i in order_range] for k in range(-half_window, half_window+1)])
    m = np.linalg.pinv(b).A[deriv] * rate**deriv * factorial(deriv)
    # pad the signal at the extremes with
    # values taken from the signal itself
    firstvals = y[0] - np.abs( y[1:half_window+1][::-1] - y[0] )
    lastvals = y[-1] + np.abs(y[-half_window-1:-1][::-1] - y[-1])
    y = np.concatenate((firstvals, y, lastvals))
    return np.convolve( m[::-1], y, mode='valid')

# %%
smooth= np.asarray(df656a.nA)
x = np.asanyarray(df656a.ds)

# %%
import time

# %%
start = time.time()
yhat = savitzky_golay(smooth, 10001, 3) # window size 51, polynomial order 3
end = time.time()
print(end - start)
plt.figure(figsize= (31,7), facecolor = 'w')
plt.plot(x,yhat, color='r')
plt.show()
# Out:
# 0.838000059128

# %%
start = time.time()
yhat = sp.signal.medfilt(smooth,5001)
end = time.time()
deltat = end-start
print(deltat)
plt.figure(figsize= (31,7), facecolor = 'w')
plt.plot(x,yhat, color='r')
plt.show()
# Out:
# 193.704999924

# %%
from scipy.signal import lfilter

n = 10000  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
start = time.time()
yy = lfilter(b,a,smooth)
end = time.time()
print(end -start)
plt.figure(figsize= (31,7), facecolor = 'w')
plt.plot(x, yy, linewidth=2, linestyle="-", c="r") 
plt.show()
# Out:
# 0.792000055313

# %%
plt.figure(figsize= (31,7), facecolor = 'w')
plt.plot(x,smooth, color = 'b')
plt.show()

# %%
yhat = sp.signal.medfilt(x2,21)

# %% [markdown]
# ### 689 nm Transition from n = 8 to n = 2 for H2 and D2

# %%
df689 = pd.read_csv('HD_5Angstroms_388nm.csv')
df689.columns = ['ds', 'nA']
df689 = df689[(df689.ds > 235) & (df689.ds < 285) ].reset_index(drop = True)
plt.figure(figsize=(31,7),  facecolor = 'w')
plt.plot(df689.ds, df689.nA)
plt.show()

# %%
x = df689.ds
n = 100  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
start = time.time()
yy = lfilter(b,a,df689.nA)
end = time.time()
print(end -start)
plt.figure(figsize= (31,7), facecolor = 'w')
plt.plot(x, yy, linewidth=2, linestyle="-", c="r") 
plt.show()
# Out:
# 0.00999999046326

# %%
x = df689.ds
n = 1000  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
start = time.time()
yy = lfilter(b,a,df689.nA)
end = time.time()
print(end -start)
plt.figure(figsize= (31,7), facecolor = 'w')
plt.plot(x, yy, linewidth=2, linestyle="-", c="r") 
plt.show()
# Out:
# 0.0370001792908

# %%
x = df689.ds
n = 3000  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
start = time.time()
yy = lfilter(b,a,df689.nA)
end = time.time()
print(end -start)
plt.figure(figsize= (31,7), facecolor = 'w')
plt.plot(x, yy, linewidth=2, linestyle="-", c="r") 
plt.show()
# Out:
# 0.128000020981

# %%
x = df689.ds
n = 7000  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
start = time.time()
yy = lfilter(b,a,df689.nA)
end = time.time()
print(end -start)
plt.figure(figsize= (31,7), facecolor = 'w')
plt.plot(x, yy, linewidth=2, linestyle="-", c="r") 
plt.show()
# Out:
# 0.267999887466

# %%
x = df689.ds
n = 10000  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
start = time.time()
yy = lfilter(b,a,df689.nA)
end = time.time()
print(end -start)
plt.figure(figsize= (31,7), facecolor = 'w')
plt.plot(x, yy, linewidth=2, linestyle="-", c="r") 
plt.show()
# Out:
# 0.317000150681

# %%
plt.figure(figsize= (31,7), facecolor = 'w')
plt.plot(x, df689.nA, x, yy)

# %% [markdown]
# We notice that as we increase the smoothing parameter, n, the lfilter seems to shift the spectrum. This would drastically change our results. Thus we will go back to the savitzky-golav implementation of the filter.

# %%
np.asarray(df689.nA)
# Out:
# array([0.20599129, 0.20601587, 0.20604037, ..., 0.21058093, 0.21056304,
#        0.2105453 ])

# %%
yhat = savitzky_golay(np.asarray(df689.nA), 50001, 3) # window size 51, polynomial order 3

# %%
yhat.shape
x = np.asarray(df689.ds)

# %%
plt.figure(figsize= (31,7), facecolor = 'w')
plt.plot(x, df689.nA, x, yhat)

# %% [markdown]
# The savitsky golav filter handles well with large smoothing parameters.

# %%
df689.nA
# Out:
# ds    247624
# nA    247624
# dtype: int64

# %%
df689.nA
# Out:
# (247624L,)
